# %%
import pandas as pd
df=pd.read_csv("../data/군집화 병합.csv",encoding="utf-8")

# %% [markdown]
# # ID 별로 일주일 간격으로 몸무게 변화 라벨링(유지:0, 감소:2, 증가:1)

# %%
for id in df['ID'].unique():
# Out:
#   File "C:\Users\jaemin\AppData\Local\Temp\ipykernel_13828\2191628334.py", line 2
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
df.tail(100)
# Out:
#             ID collect_datetime  gender  grade  height  weight  step_count  \
# 59414  #ZZLSSL       2022-10-04     1.0    6.0   153.0    68.0      2103.0
# 59415  #ZZLSSL       2022-10-05     1.0    6.0   153.0    68.0      2103.0
# 59416  #ZZLSSL       2022-10-06     1.0    6.0   153.0    68.0      2103.0
# 59417  #ZZLSSL       2022-10-07     1.0    6.0   153.0    68.0      2103.0
# 59418  #ZZLSSL       2022-10-08     1.0    6.0   153.0    68.0      2103.0
# ...        ...              ...     ...    ...     ...     ...         ...
# 59509  #ZZLSSL       2023-01-07     1.0    6.0   153.0    68.0      2103.0
# 59510  #ZZLSSL       2023-01-08     1.0    6.0   153.0    68.0      2103.0
# 59511  #ZZLSSL       2023-01-09     1.0    6.0   153.0    68.0      2103.0
# 59512  #ZZLSSL       2023-01-10     1.0    6.0   153.0    68.0      2103.0
# 59513  #ZZLSSL       2023-01-11     1.0    6.0   153.0    68.0      2103.0
#
# ...

# %%
df[df['ID']=='#ZZLSSL']
# Out:
#              ID collect_datetime  gender  grade  height  weight  step_count  \
# 190343  #ZZLSSL       2022-07-14     1.0    6.0   153.0    68.0      2103.0
# 190344  #ZZLSSL       2022-07-14     1.0    6.0   153.0    68.0      2103.0
# 190345  #ZZLSSL       2022-07-15     1.0    6.0   153.0    68.0      2103.0
# 190346  #ZZLSSL       2022-07-15     1.0    6.0   153.0    68.0      2103.0
# 190347  #ZZLSSL       2022-07-16     1.0    6.0   153.0    68.0      2103.0
# ...         ...              ...     ...    ...     ...     ...         ...
# 190702  #ZZLSSL       2023-01-09     1.0    6.0   153.0    68.0      2103.0
# 190703  #ZZLSSL       2023-01-10     1.0    6.0   153.0    68.0      2103.0
# 190704  #ZZLSSL       2023-01-10     1.0    6.0   153.0    68.0      2103.0
# 190705  #ZZLSSL       2023-01-11     1.0    6.0   153.0    68.0      2103.0
# 190706  #ZZLSSL       2023-01-11     1.0    6.0   153.0    68.0      2103.0
#
# ...
