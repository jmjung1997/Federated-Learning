# %%
import pandas as pd

# %%
eatcalory_sum_data=pd.read_excel('./data/eatcalory_sum.xlsx', sheet_name=1)

# %%
eatcalory_sum_data.head()
# Out:
#         ID  2022-07-14 00:00:00  2022-07-15 00:00:00  2022-07-16 00:00:00  \
# 0  #AAGQKY                 72.0                 72.0                 72.0
# 1  #ACGRQP              10079.0              10079.0              10079.0
# 2  #AEGMOD               5678.0               5678.0               5678.0
# 3  #AJXZPA                  NaN                  NaN                  NaN
# 4  #ALZXWR                  6.0                  6.0                  6.0
#
#    2022-07-17 00:00:00  2022-07-18 00:00:00  2022-07-19 00:00:00  \
# 0                 72.0                 72.0                 72.0
# 1              10079.0              10079.0              10079.0
# 2               5678.0               5678.0               5678.0
# 3                  NaN                  NaN                  NaN
# 4                  6.0                  6.0                  6.0
#
#    2022-07-20 00:00:00  2022-07-21 00:00:00  2022-07-22 00:00:00  ...  \
# ...

# %%
eatcalory_sum_data.isnull().sum()
# Out:
# ID                       0
# 2022-07-14 00:00:00    183
# 2022-07-15 00:00:00    183
# 2022-07-16 00:00:00    183
# 2022-07-17 00:00:00    183
# 2022-07-18 00:00:00    184
# 2022-07-19 00:00:00    184
# 2022-07-20 00:00:00    184
# 2022-07-21 00:00:00    184
# 2022-07-22 00:00:00    184
# 2022-07-23 00:00:00    184
# 2022-07-24 00:00:00    184
# 2022-07-25 00:00:00    184
# 2022-07-26 00:00:00    184
# 2022-07-27 00:00:00    184
# 2022-07-28 00:00:00    184
# 2022-07-29 00:00:00    184
# 2022-07-30 00:00:00    184
# 2022-07-31 00:00:00    184
# 2022-08-01 00:00:00    184
# 2022-08-02 00:00:00    183
# 2022-08-03 00:00:00    184
# 2022-08-04 00:00:00    184
# 2022-08-05 00:00:00    184
# 2022-08-06 00:00:00    184
# 2022-08-07 00:00:00    184
# 2022-08-08 00:00:00    184
# 2022-08-09 00:00:00    184
# 2022-08-10 00:00:00    184
# 2022-08-11 00:00:00    182
# 2022-08-12 00:00:00    184
# 2022-08-13 00:00:00    184
# 2022-08-14 00:00:00    184
# 2022-08-15 00:00:00    184
# ...

# %%
eatcalory_sum_data
# Out:
#           ID  2022-07-14 00:00:00  2022-07-15 00:00:00  2022-07-16 00:00:00  \
# 0    #AAGQKY                 72.0                 72.0                 72.0
# 1    #ACGRQP              10079.0              10079.0              10079.0
# 2    #AEGMOD               5678.0               5678.0               5678.0
# 3    #AJXZPA                  NaN                  NaN                  NaN
# 4    #ALZXWR                  6.0                  6.0                  6.0
# ..       ...                  ...                  ...                  ...
# 317  #ZNPAMO                  NaN                  NaN                  NaN
# 318  #ZNRYPQ                  NaN                  NaN                  NaN
# 319  #ZRKRKP                 36.0                 36.0                 36.0
# 320  #ZWOHRX                694.0                694.0                694.0
# 321  #ZZLSSL                  NaN                  NaN                  NaN
#
# ...

# %%
eatcalory_sum_data_new=eatcalory_sum_data.where(pd.notnull(eatcalory_sum_data), eatcalory_sum_data.mean(), axis='columns')

# %%
eatcalory_sum_data_new.head()
# Out:
#         ID  2022-07-14 00:00:00  2022-07-15 00:00:00  2022-07-16 00:00:00  \
# 0  #AAGQKY            72.000000            72.000000            72.000000
# 1  #ACGRQP         10079.000000         10079.000000         10079.000000
# 2  #AEGMOD          5678.000000          5678.000000          5678.000000
# 3  #AJXZPA          1624.690647          1715.244604          1602.809353
# 4  #ALZXWR             6.000000             6.000000             6.000000
#
#    2022-07-17 00:00:00  2022-07-18 00:00:00  2022-07-19 00:00:00  \
# 0            72.000000            72.000000            72.000000
# 1         10079.000000         10079.000000         10079.000000
# 2          5678.000000          5678.000000          5678.000000
# 3          1587.010791          1542.018116          1564.800725
# 4             6.000000             6.000000             6.000000
#
#    2022-07-20 00:00:00  2022-07-21 00:00:00  2022-07-22 00:00:00  ...  \
# ...

# %%
eatcalory_sum_data_new.to_excel('./data/eatcalory_sum_data_new_NOTNULL.xlsx', index=False)

# %%
data=eatcalory_sum_data["ID"].unique()
