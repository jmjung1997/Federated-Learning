# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from sklearn.preprocessing import MinMaxScaler
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense,Dropout,Activation
from torch.utils.data import TensorDataset, DataLoader
from tensorflow.python.keras import metrics
from tensorflow.python import keras
import tensorflow as tf
import matplotlib.pyplot as plt
import os
from imblearn.over_sampling import SMOTE
import math
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_excel('./optimal_data2/'+'Continous_2weeks_1day_1term.xlsx')
df.head()
X=df.iloc[:,[1,3,4,5,6,7]]
y=df.iloc[:,-1]

# %%
X
# Out:
#           1     3    4    5    6      7
# 0      45.0  72.0  0.0  0.0  0.0  148.0
# 1      45.0  72.0  0.0  0.0  0.0  148.0
# 2      45.0  72.0  0.0  0.0  0.0  148.0
# 3      45.0  72.0  0.0  0.0  0.0  148.0
# 4      45.0  72.0  0.0  0.0  0.0  148.0
# ...     ...   ...  ...  ...  ...    ...
# 27043  68.0   0.0  0.0  0.0  0.0  153.0
# 27044  68.0   0.0  0.0  0.0  0.0  153.0
# 27045  68.0   0.0  0.0  0.0  0.0  153.0
# 27046  68.0   0.0  0.0  0.0  0.0  153.0
# 27047  68.0   0.0  0.0  0.0  0.0  153.0
#
# [27048 rows x 6 columns]
